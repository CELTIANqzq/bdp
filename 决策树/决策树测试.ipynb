# %%
import pandas as pd
data = pd.read_csv("/Users/zhaozihao/Desktop/年.csv")

# %%
data.head()
# Out:
#    bookID                                              title  \
# 0    8253     Little Town on the Prairie  (Little House  #7)
# 1   11101        First Comes Love (Hot Water  California #1)
# 2   28193                           When Santa Fell to Earth
# 3   25047  The Case of the Stinky Science Project (Jigsaw...
# 4   17800                                  Dance Dance Dance
#
#                                          authors  average_rating        isbn  \
# 0            Laura Ingalls Wilder/Garth Williams            4.19    60885432
# 1                               Christie Ridgway            3.81   380818957
# 2  Cornelia Funke/Paul   Howard/Oliver G. Latsch            3.76  043978204X
# 3        James Preller/John Speirs/James Preller            3.83   439114284
# 4                                Haruki Murakami            4.04    99448769
#
#          isbn13 language_code  num_pages  ratings_count  text_reviews_count  \
# ...

# %%
data.average_rating.value_counts()
# Out:
# 4.00    199
# 3.96    183
# 4.02    164
# 3.94    160
# 3.92    155
#        ...
# 2.92      1
# 2.77      1
# 2.93      1
# 2.89      1
# 4.88      1
# Name: average_rating, Length: 204, dtype: int64

# %%
data.describe()
# Out:
#              bookID  average_rating        isbn13     num_pages  \
# count  10000.000000    10000.000000  1.000000e+04  10000.000000
# mean   21266.538300        3.935645  9.762579e+12    336.340000
# std    13081.040856        0.345856  4.034836e+11    234.721368
# min        1.000000        0.000000  8.987060e+09      0.000000
# 25%    10230.000000        3.780000  9.780000e+12    194.000000
# 50%    20261.000000        3.960000  9.780000e+12    300.000000
# 75%    31986.750000        4.130000  9.780000e+12    416.000000
# max    45641.000000        5.000000  9.790000e+12   4736.000000
#
#        ratings_count  text_reviews_count          year
# count   1.000000e+04        10000.000000  10000.000000
# mean    1.874233e+04          555.690600   2000.189100
# std     1.178498e+05         2672.388675      8.172504
# min     0.000000e+00            0.000000   1900.000000
# 25%     1.060000e+02            9.000000   1998.000000
# 50%     7.440000e+02           47.000000   2003.000000
# ...

# %%
feature = data[["isbn13","num_pages","ratings_count","text_reviews_count","year"]]
target = data[["average_rating"]]

# %%
from sklearn import tree
model = tree.DecisionTreeClassifier()
model = model.fit(feature,target.astype(int))

# %%
import graphviz
dot_data = tree.export_graphviz(model,out_file=None)
graph = graphviz.Source(dot_data)
graph.render("train结果")
# Out:
# 'train结果.pdf'
